# %% [markdown]
# # BeautifulSoup - Scrape US Universities offering Analytics Program
#
# You may find US universities offering Analytics Program from this webpage.
# http://www.mastersindatascience.org/specialties/business-analytics/
#
# We will try to extract the univ names.

# %% [markdown]
# We use two packages
#
# - ```urllib2```: for making http requets.
# - ```bs4``` (beautifulsoup4): for parsing the content of the page.

# %%
from bs4 import BeautifulSoup
import urllib.request, urllib.error, urllib.parse

# %%
#get page
source = urllib.request.urlopen("http://www.mastersindatascience.org/specialties/business-analytics/")

# %% [markdown]
# #### Let's try using a fancy header:

# %%
import time
from urllib.request import FancyURLopener  # This is library that helps us create the headless browser
from random import choice #This library helps pick a random item from a list

user_agents = [
    'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16',
    'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/7046A194A',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246'
]

class MyOpener(FancyURLopener, object):
    version = choice(user_agents)

myopener = MyOpener()
page=myopener.open("http://www.mastersindatascience.org/specialties/business-analytics/")

html = page.read().decode('utf-8')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: MyOpener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   app.launch_new_instance()

# %%
html
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\n<head >\n<meta charset="UTF-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1" />\n<title>Master&#039;s in Business Analytics Programs | Find Schools</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v7.9 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Search universities across the US that offer Master&#039;s in Business Analytics programs - learn about curriculum, tuition, pre-requisites, and more."/>\n<link rel="canonical" href="https://www.mastersindatascience.org/specialties/business-analytics/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Master&#039;s in Business Analytics Programs | Find Schools" />\n<meta property="og:description" content="Search universities across the US that offer Master&#039;s in Business Analytics programs - learn about curriculum, tuition, pre-requisites, and more." />\n<meta property="og:url" content="https://www.mastersindatascience.org/specialties/business-analytics/" />\n<meta property="og:site_name" content="Master&#039;s in Data Science" />\n<meta property="article:section" content="Uncategorized" />\n<meta property="og:image" content="https://www.mastersindatascience.org/wp-content/uploads/2014/09/GED.png" />\n<meta property="og:image:secure_url" content="https://www.mastersindatascience.org/wp-content/uploads/2014/09/GED.png" />\n<meta property="og:image:width" content="565" />\n<meta property="og:image:height" content="565" />\n<meta name="twitter:card" content="summary" />\n<meta name="twitter:description" content="Search universities across the US that offer Master&#039;s in Business Analytics programs - learn about curriculum, tuition, pre-requisites, and more." />\n<meta name="twitter:title" content="Master&#039;s in Business Analytics Programs | Find Schools" />\n<meta name="twitter:image" content="https://www.mastersindatascience.org/wp-content/uploads/2014/03/Data-Breaches-150x150.png" />\n<!-- / Yoast SEO plugin. -->\n\n<link rel=\'dns-prefetch\' href=\'//platform.twitter.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel=\'stylesheet\' id=\'eleven40-pro-theme-css\'  href=\'https://www.mastersindatascience.org/wp-content/themes/eleven40-pro/style.css\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'apss-font-awesome-css\'  href=\'https://www.mastersindatascience.org/wp-content/plugins/accesspress-social-share/css/font-awesome/font-awesome.min.css\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'apss-font-opensans-css\'  href=\'//fonts.googleapis.com/css?family=Open+Sans&#038;ver=4.9.8\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'apss-frontend-css-css\'  href=\'https://www.mastersindatascience.org/wp-content/plugins/accesspress-social-share/css/frontend.css\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'ctf_styles-css\'  href=\'https://www.mastersindatascience.org/wp-content/plugins/custom-twitter-feeds/css/ctf-styles.css\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'google-font-css\'  href=\'//fonts.googleapis.com/css?family=Lato%3A400%2C700%7COswald%3A300%2C400%2C700&#038;ver=2.6.1\' type=\'text/css\' media=\'all\' />\n<link rel=\'stylesheet\' id=\'bootstrap-css\'  href=\'https://www.mastersindatascience.org/wp-content/themes/eleven40-pro/bootstrap.min.css\' type=\'text/css\' media=\'all\' />\n<script type=\'text/javascript\' src=\'https://www.mastersindatascience.org/wp-includes/js/jquery/jquery.js\'></script>\n<script type=\'text/javascript\' src=\'https://platform.twitter.com/widgets.js\'></script>\n<!--[if lt IE 9]>\n<script type=\'text/javascript\' src=\'https://www.mastersindatascience.org/wp-content/themes/genesis/lib/js/html5shiv.min.js\'></script>\n<![endi ...

# %%
#BeautifulSoup takes a string object and parse out the document structure
# and turn it into a BeautifulSoup object.
soup = BeautifulSoup(html, "html5lib")

# %% [markdown]
# Now you should navigate to http://www.mastersindatascience.org/specialties/business-analytics/ using Chrome browser.
#
# Right click on a url, choose  "inspect element" to inspect HTML source.
#
# How can we accurately locate them?

# %%
# From the inspecting of the elements we can see that all the university names are embeddes in <h3 class = "schoolname">
# we use find_all to find all the names which has a class of "schoolname"
for university in soup.find_all('h3',class_='schoolname'):
    print(university.string)
    #prints out the string value (name of the university)
# Out:
# Auburn University
# The University of Alabama
# University of Alabama in Huntsville
# Arizona State University
# University of Arizona
# University of Arkansas
# California Polytechnic State University-San Luis Obispo
# California State University-East Bay
# Golden Gate University-San Francisco
# San Jose State University
# Santa Clara University
# University of California-Davis
# University of California-Irvine
# University of California-Los Angeles
# University of California-San Diego
# University of San Francisco
# University of Southern California
# University of the Pacific
# American Sentinel University
# Colorado Technical University
# University of Colorado Boulder
# University of Colorado Denver
# University of Denver
# Quinnipiac University
# University of Bridgeport
# University of Connecticut
# University of Delaware
# American University
# George Washington University
# Georgetown University
# Florida Atlantic University
# Full Sail University
# Jacksonville University
# Nova Southeastern University
# University of Central Florida
# University of Florida
# University of Miami
# University of South Florida-Main Campus
# Georgia Institute of Technology
# Georgia State University
# Kennesaw State University
# Mercer University
# University of Georgia
# Hawaii Pacific University
# Benedictine University
# Lewis University
# Loyola University Chicago
# Northwestern University
# University of Chicago
# University of Illinois at Chicago
# University of St Francis
# Indiana University Bloomington
# Purdue University
# University of Notre Dame
# Valparaiso University
# Aston University
# Deakin University
# EISTI
# IE School of Human Sciences and Technology
# Institute of Technology Blanchardstown
# National University of Singapore
# Queen's University
# Radboud Universiteit Nijmegen
# Stiftung Universitat Hildheim
# Universitat Pompeu Fabra
# University College Dublin
# University of Kent
# University of Manchester
# University of Southampton
# University of Strathclyde
# University of Surrey
# University of Warwick
# University of Westminster
# Utrecht University
# Vrije Universiteit Amsterdam
# York University
# Iowa State University
# Loras College
# University of Iowa
# Kansas State University
# University of Kansas
# Bellarmine University
# Louisiana State University
# University of Louisiana-Monroe
# University of Southern Maine
# Notre Dame of Maryland University
# University of Maryland-College Park
# Harvard University
# Babson College
# Bentley University
# Boston University
# Clark University
# Massachusetts Institute of Technology
# Merrimack College
# Northeastern University
# Suffolk University
# University of Massachusetts Amherst
# University of Massachusetts-Boston
# Central Michigan University
# Grand Valley State University
# Michigan State University
# Oakland University
# University of Michigan-Dearborn
# Wayne State University
# Saint Mary's University of Minnesota
# University of Minnesota-Twin Cities
# University of St. Thomas
# Grantham University
# Maryville University
